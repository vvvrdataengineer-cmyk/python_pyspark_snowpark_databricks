# %% [markdown]
# # Default language is python.
# # %md markdown : have more options to create document.
#   # text formats.
#   # images.
#   # Links (HTML) : Hyperlink.
#   # Tables.
#
# # %run   : To run another notebook from the current notebook.
#
# # dbutils.fs.help() : dbutils is more useful as we can use in python program.
#
# # display() : it gives more flexible output as tabular format.

# %% [markdown]
# Exports:
# # DBC archive.
# # source file.
# # IPython notebook.
# # HTML
#
# Imports:

# %%
dbutils.notebook.help()

# %%
# Calling one notebook from another notebook.

dbutils.notebook.run("./child-notebook",10)

# %%
# Restore the version:
    #

# %%
dbutils.notebook.exit()
dbutils.notebook.run()
