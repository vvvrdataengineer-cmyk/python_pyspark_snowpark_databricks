# %%
#Parametarized code.
dbutils.widgets.help()

# %%
# create the widget
dbutils.widgets.text("msg","this is test parameter message")

# %%
message = dbutils.widgets.get("msg")
#dbutils.widgets.set("msg","override msge")  #not working need to check.
print(message)
message="override"
print(message)
print(dbutils.widgets.get("msg"))
