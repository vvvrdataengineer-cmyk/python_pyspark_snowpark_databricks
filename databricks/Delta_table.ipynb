# %%
# %sql
use catalog workspace;

# %%
# %sql
create table emp_jan11 (id int, name string) using delta;

# %%
# %sql
describe detail emp;

# %%
# %sql
update emp set sal = 40000 where deptno=20;
describe history emp;

# %%
dbutils.fs.ls("/workspace/tables/emp/_delta_log")
