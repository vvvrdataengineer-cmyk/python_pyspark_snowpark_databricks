# %% [markdown]
# Databricks Magic Commands

# %%
#Language Magic Commands
# %md
# %scala
# %sql
# %python
# %md
# %r

# %%
#%fs : file system  : over the distributed system.
#file system utility allow mount cloud directories to dbfs. s3, ADLS directories to dbfs.
#%fs.mount
#ls /databricks-datasets.
# %fs

# %% [markdown]
# %sh : to run shell commands.
# tail  /databricks-datasets  --to get last files.

# %%
# %lsmagic

# %%
#To list environment variables.
# %env?

# %%
# %env??

# %%
# %pip??

# %% [markdown]
# db utilities:
# 1.credentials.
# 2.data.
# 3.fs.
# 4.jobs.
# 5.library.
# 6.meta.
# 7.notebook.
# 8.secrets.
# 9.widgets.
# 10.preview.

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.help("cp")

# %%
# %fs

# %%
ls /databricks-datasets

# %%
dbutils.fs.ls("/databricks-datasets")

# %%
# using only fs we can not loop so, we should use dbutils.fs

for folder_name in dbutils.fs.ls("/databricks-datasets/"):
    print(folder_name.path)
