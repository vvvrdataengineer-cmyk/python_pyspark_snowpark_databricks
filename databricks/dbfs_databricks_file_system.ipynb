# %%
# Databricks file system:
# -- for every databricks workspace there is a dedicated default storage file system.
# -- But not recommended store customers data.

# %%
# dbfs is distributed file system abstraction on top of scalable cloud storage integrated into a databricks workspace and available on databricks clusters.

# dbfs is default file system, like directory.

# can be accessible this dbfs from:
                #-- databricks noteboks.
                #-- databricks CLI.
                #-- databricks API.

# %%
# working with dbfs root storage: directly can not access that default storage account.

# %%
# %fs ls dbfs:/

# %%
# /databricks-datasets/  -- is a sample data directory which is default.

# %%
# %fs ls dbfs:/databricks-datasets/

# %%
# %fs ls dbfs:/databricks-results/

# %%
# %fs ls /databricks-results/

# %%
# %fs ls file:/      # system data, local file system of driver machine.

# %%
# %fs mounts   # shows all mounted locations.

# %%
# Q. How to create storage account and mount it?

# %% [markdown]
# what are databricks storage level options?
# 1. Metastore.
# 2. workspace
# 3. catalog.
# 4. schema level.
# 5. Table level.

# %% [markdown]
# Mounting ADLS to DBFS:
#
# creating your dbfs mount for data storage:
# 1. Create ADLS Gen2 storage account.
# 2. Create storage container in your storage account.
# 3. Create Azure service principal and secret.
# 4. Grant acces to service principal for storage account.
# 5. Mount storage container.
#
# Q. What is client ID (Application)?
#
# Q. What is Tenant ID (Directory)?
#
# Mount storage container:
# -- use API to mount storage container.
#
#
# Mount the container:
# dbutils.fs.mount(
#   source=
#   ,mount_point = "/mnt/mount_name",
#   extra_configs = configs)

# %% [markdown]
# # list contents of your mount point

# %%
# %fs ls /mnt

# %%
# %fs ls /mnt/files/sample_data/

# %%
# %fs mounts

# %% [markdown]
# unmount directory
#
# note: if unmount also
# still we do not lose data.
# still data available at continer level.

# %%
# %fs unmount /mnt/files/

# %% [markdown]
# Azure vault:
#             Use to store secret info instead of expose in code.
#
# dbutils.secret.get
