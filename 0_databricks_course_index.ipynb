# %% [markdown]
# **Practiced databricks content**

# %% [markdown]
# **easydata**
#
# 1. databricks intro.
# 2. what is data lakehouse & databricks data intelligence platform:
#  Benefits fo databricks lakehouse.
# 3. databricks high level architecture:
#  understanding control plane and data plane.
#  roles in databricks.
# 4. setup databricks on azure:
#  create our first databricks workspace.
#  how to create dbx free account.
# 5. understand databricks account console.
#  user management in databricks.
#  workspace management.
# 6. databricks workspace and notebooks:
#  cell magic commands.
#  version history.
#  commands.
#  variables.
# 7. how databricks work with azure:
#  managed storage container.
#  databricks clusters using azure VMS.
# 8. what is unity catalog and databricks governance:
#  what is metastore.
#  unity catalog object model?
# 9. what are managed tables and external tables?
# dbfs.
# 10. enable unity cataglog and setup metastore.
#  how to setup unity catalog for databricks workspace.
# 11. catalog, external location & storage credentials in unity catalog.
#  catalog with external location.
# 12. schema's with external location in unity catalog.
#  managed table data location in unity catalog.
# 13. managed and external tables in unity catalog Vs legacy Hive metastore.
#   UNDROP tables in databricks.
# 14. delta tables deep shallow clones:
#  temporary and permanent views.
#  list catalog, schemas and tables.
# 15. delta tables merge and upserts: scd 1 in delta, soft delete with incremental data using merge.
# 16. delta tables liquid clustering and deletion vectors:
#  optimize delta tables.
#  delta clustering.
# 17. volumes- managed and external in databricks.
#  volumes in databricks unity cataglog.
#  file sin volumes.
# 18. dbutils command:
#  databricks utilities.
#  create widgets in databricks notebooks.
#  dbutils fs usage.
# 19. orchestrating notebook jobs, schedules using parameters.
#  run notebook from another notebook.
# 20. databricks computes: all purpose and job:
#  access modes.
#  cluster policies.
#  cluster permissions.
# 21. custom cluster policy in databricks.
#  create instance pools.
#  warm instance pool.
#  22. workflows, jobs and tasks:
#   pass values within tasks.
#   if else condition.
# 23. databricks copy into command:
#  copy into metadata.
#  idempotent pipeline.
#  exactly once processing.
# 24. auto loader in databricks:
#  autoloader schema evalution modes.
#  file detection mode in autoloader.
# 25. medallion architecture in data lakehouse.
#  use of bronze, silver and gold layers.
# 26. DLT: streaming tables and materialized views in DLT.
# 27. DLT incremental load / internals:
#  add or modify columns.
#  rename table.
#  data lineage.
# 28. DLT append flow: union & autoloader.
#  pass parameters in DLT pipeline.
#  generate tables dynamically.
# 29. DLT SCD 2 and SCD 1 table:
#  apply changes.
#  CDC.
#  bulk loading SCD2 table.
#  delete/truncate SCD table.
# 30. DLT data quality and expectations.
#  monitor DLT pipelines using SQL.
#  define DQ rule : observability.
#  31. DLT truncate load source:
#   workflow file arrival triggers.
#   full refresh.
#   schedule DLT pipelines.
# 32. databricks secret management and secret scopes:
#  save secrets in databricks.
#  use of azure key vault.
# 33. user management in databricks:
#  how to add users, service principal and groups in unity catalog.
# 34. object level security or permissions in unity catalog.
#  manage object privileges in unity catalog.
# 35. functions in unity catalog using databricks SQL.
#  SCALAR and table user defined functions.
# 36. row level filters in UC.-- unity catalog.
#  filters senstive data in UC table using row level security.
# 37. column level masking in UC.-- unity catalog.
#  mask senstive column in unity catalog table using column masking.
# 38. workspace catalog binding in unity catalog in databricks:
#  limit catalog access.
#  share cataglog.
#  39. delta sharing in databricks.
#   databricks express edition.
#   share data outside your organization.
# 40. serverless compute for notebooks, jobs, DLT, ML and warehoueses.
#  architecture of serverless.
# 41. data warehousing using DBSQL.
#  SQL warehouse on databricks.
#  SQL query performance tunning.
# 42. streaming tables and materialized views in DBSQL.
#  background working.
#  schedule data refresh.
# 43. lakehouse federation or query federation in databricks:
#  query external database.
#  foreign catalog.
# 44. databricks SQL alerts.
#  configure alert schedule and destinations.
# 45. metric views in databricks unity catalog.
#  design semantic model.
#  measures and attributes.
# 46. AIBI dashboards & visualizations.
#  consumer access in databricks.
#  forecasting reports.
# 47. AIBI genie space in databricks:
#  use natural language to query data.
# 48. databricks GIT folders:
#  configure GIT repo with databricks using azure devops repo.
# 49. databricks CLI/ install and authenticate databricks CLI.
#  V2M and M2M authentication.
# 50. DB asset bundles, configure production grade DAB's.
#  CICD using DAB's(IAC)
# 51. setup azure devops pipeline with DB assest bundles.
#  complete CICD process.
# 52. lakeflow spark declarative pipelines:
#  new pipeline code editor.
#  auto cdc
#  external target sinks.
