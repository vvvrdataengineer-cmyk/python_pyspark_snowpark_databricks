# %%
# %sql
CREATE VOLUME workspace.raw.raw_volume;--instead of dbfs.

# %%
# %fs ls /Volumes/workspace/raw/raw_volume

# %%
files = dbutils.fs.ls("/Volumes/workspace/raw/raw_volume")
display(files)

# %%
dbutils.fs.mkdirs("/Volumes/workspace/raw/raw_volume/aw_source")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/raw/raw_volume/raw_source/airports")

# %%
dbutils.fs.mkdirs("/Volumes/workspace/raw/raw_volume/raw_source/flights")

# %%
# creating folders in volumes.
dbutils.fs.mkdirs("/Volumes/workspace/raw/raw_volume/raw_source/bookings")
dbutils.fs.mkdirs("/Volumes/workspace/raw/raw_volume/raw_source/customers")

# %%
# %sql
create schema bronze;

# %%
# %sql
create schema workspace.silver;

# %%
# %sql
create schema workspace.gold;

# %%
# %sql
create volume workspace.bronze.bronze_volume;

# %%
# %sql
create volume workspace.silver.silver_volume;

# %%
# %sql
create volume workspace.gold.gold_volume;
