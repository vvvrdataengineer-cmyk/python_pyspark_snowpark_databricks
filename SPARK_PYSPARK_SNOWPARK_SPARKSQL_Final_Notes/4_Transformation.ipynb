# %% [markdown]
# **Q. WHAT IS DSL?**

# %% [markdown]
# **Q. what is Transformation?**
# - Modify or convert data into meaningful information as per business need is transformation.
#     - Narrow Transformation.
#     - Wide Transformation.
# - To Trigger the execution we need to call an Action.
#
# **3 Action Types:**
# 1. View data in console.
# 2. Collect data to native language.
# 3. Write data to output data sources.

# %% [markdown]
# **Transformation Keyword list**
# - withColumn
# - withRenameColumn
# - dropna

# %% [markdown]
# **Q. what is difference between map and flatMap:**
# - Map and FlatMap are the functions applied on Spark rdd or datasets.
# - Map Applies the function or operation.
# - FlatMap Applies the function or operation along with Flattening the data.

# %% [markdown]
# **Q. GroupBykey vs Reduceby key?**
# - Both reduceByKey and groupByKey result in wide transformations which means both triggers a shuffle operation.
# - The key difference between reduceByKey and groupByKey is that reduceByKey does a map side combine and groupByKey does not do a map side combine

# %% [markdown]
# **Q. what is Spark Windowing?**
# - Spark Window functions are used to calculate results such as the rank, row number e.t.c over a range of input rows

# %%
val windowf = Window
  .partitionBy($"department")
  .orderBy($"assetValue" desc)

df.withColumn("col3", dense_rank() over windowf)
  .filter("col3=2")
