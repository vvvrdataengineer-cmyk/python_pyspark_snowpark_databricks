# %% [markdown]
# **creating database/schema:**

# %%
# %sql
create database my_db;

# %% [markdown]
# **listing files in directory:**

# %%
dbutils.fs.ls("/Volumes/workspace/my_db/images/")

# %% [markdown]
# **Moving files from one directory to another directory:**

# %%
for file_info in dbutils.fs.ls("/Volumes/workspace/my_db/images/"):
    if file_info.isFile():
        dbutils.fs.mv(file_info.path, f"/Volumes/workspace/my_db/images/spark/{file_info.name}")
