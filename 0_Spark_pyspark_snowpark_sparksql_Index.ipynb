# %% [markdown]
# **Spark Index:**
#
# 1. Spark Introduction.
# 2. Spark Architecture.
# 3. Create Spark Session.
# 4. Creating DataFrame.
# 5. Column, Rows, Schema
# 6. Transformations : Select, col, expr, SelectExpr, cast
# 7. StructType, StructField, StringType, IntergerType.
# 8. How to select required columns.
# 9. Column Aliases, alias
# 10. show()-truncate=False,printSchema()
# 11. _parse_datatype_string()
# 12. where,withColumn,withColumns, WithColumnrenamed, lit,drop,limit
# 13. when for case, regexp_replace, to_date, current_date,current_timestamp
# 14. coalesce,
# 15. Writing/reading DataFrame to csv and vice vera: write/read, format, save, option(header,inferSchema),load, columnNameOfCorruptedRecord
# Spark Read Modes(PERMISSIVE, DROPMALFORMED, FAILFAST)
# 16. unionAll, unionByName
# 17. asc,desc,asc_nulls_last,desc_nulls_last, orderBy, groupBy
# 18. count,sum,avg,min
# 19. distinct, Window, row_number
# 20. repartition, getNumPartitions, coalesce, spark_partition_id
# 21. join, isNull
# 22. loading json,parquet and parsing.
# 	recursiveFieldLookup, from_json, to_json, explode
# 23. mode: append, overwrite, ignore, error,
# 24. partitionBy,
# 25. spark-submit
# 26. udf
# 27. DAG, Shuffle, Expalin Plan, AQE, Broadcast join
# 28. range
# 29. defaultParallelism
# 30. Cache Vs persistent
# 31. Boradcast variables, Accumulator variable.**

# %% [markdown]
# ** easy data**
# **pyspark**
# 1. Pyspark tutorial intro.
# 2. how spark works- drivers and executors, how spark divide job in stages.
# 3. spark transformations and actions, why spark prefers lazy evaluation, what are partitions in spark.
# 4. spark dataframes and execution plans. spark logical and physical execution planning, what are DAG's.
# 4.2 setup pyspark in local machine with jupyter lab, physical local machine setup.
# 5. understanding spark session & create first dataframe. create spark session object.-- spark UI.
# 6. basic structured transformations, write spark dataframe schema, ways to write DF columns.
# 7. cast column, add column, static column value, rename.
# 8. working with strings, dates, null: regex replace, convert string to date, transform NULL.
# 9. sorting data, union and aggregation in spark: diff union and union all, having clause.
# 10. window functions, unique data databricks community cloud: second highest salary, spark expr.
# 11. data repartitioning and pyspark joins: coalesce Vs repartition, spark data partition, joins.
# 12. understand spark UI:
#  read csv files and read modes.
#  spark inferschema option.
#  drop malformed.
# 13. read complex file formats:
#  parquet
#  orc
#  performance benefits of parquet.
#  recursive file lookup.
# 14. read, parse or flatten JSON data:
#  json file with schema.
#  from_json.
#  to_json.
#  multiline json.
# 15. how spark writes data:
#  write modes in spark.
#  write data with partition.
#  default parallesm.
# 16. understand spark executions on cluster:
#  cluster manager.
#  cluster deployment modes.
#  spark submit.
# 17. user defined function: UDF
#  how spark works with udf.
#  how to register python udf.
# 18. understand DAG, explain plans & spark shuffle with tasks:
#  skipped stage.
#  benefits of shuffle write.
# 19. understand and optimize shuffle in spark.
# 20. data caching in spark:
#  cache vs persist.
#  spark storage level with persist.
#  partial data caching.
# 21. broadcast variable and accumulators.
#  how to use spark broadcast variables.
# 22. optimize joins in spark:
#  understanding bucketing for faster joins.
#  sort merge join.
#  broad cast join.
# 23. Static Vs Dynamic resource allocation in spark:
#  dynamic allocation Vs databricks scale up.
# 24. fix skewness and spillage with salting in spark.
#  salting technique.
#  how to identify skewness.
# 25. AQE aka adaptive query execution in spark:
#  coalesce shuffle partitions.
#  skew partitions fix.
# 26. spark SQL, hints, spark catalog and metastore:
#  hints in spark SQL query.
#  SQL functions and joins.
# 28. get started with delta lake using databricks:
#  benefits and features of delta lake.
#  time travel.
# 29. optimize data scanning with partitioning in spark:
#  how partitioning data works.
#  optimize jobs.
# 30. data skipping and z-ordering in delta lake tables:
#  optimze and data compaction delta lake tables.
# 31. delta tables-deletion vectors and liquid clustering:
#  optimize delta tables.
#  delta clustering.
# 32. spark memory management: why OOM errors in spark.
# 33. what is spark connect:
#  spark connect vs spark session.
#  setup spark connect server with cluster.
